# %% [markdown]
# GraphSAGE
# - cora: ~0.8330
# - citeseer: ~0.7110
# - pubmed: ~0.7830

# %%
# !pip install dgl
# !pip install dgl-cu101
# Out:
# Requirement already satisfied: dgl in /usr/local/lib/python3.6/dist-packages (0.4.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (1.4.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.6/dist-packages (from dgl) (2.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from dgl) (1.17.5)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.1->dgl) (4.4.1)
# Requirement already satisfied: dgl-cu101 in /usr/local/lib/python3.6/dist-packages (0.4.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from dgl-cu101) (1.4.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from dgl-cu101) (1.17.5)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.6/dist-packages (from dgl-cu101) (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.1->dgl-cu101) (4.4.1)

# %%
import argparse
import time
import numpy as np
import networkx as nx
import torch
import torch.nn as nn
import torch.nn.functional as F
from dgl import DGLGraph
from dgl.data import register_data_args, load_data
from dgl.nn.pytorch.conv import SAGEConv

# %%
 dropout=0.5
 gpu=0
 lr=1e-2
 epochs=200
 n_hidden=16
 n_layers=1
 weight_decay=5e-4
 aggregator_type="gcn"

# %%
class GraphSAGE(nn.Module):
    def __init__(self,
                 g,
                 in_feats,
                 n_hidden,
                 n_classes,
                 n_layers,
                 activation,
                 dropout,
                 aggregator_type):
        super(GraphSAGE, self).__init__()
        self.layers = nn.ModuleList()
        self.g = g

        # input layer
        self.layers.append(SAGEConv(in_feats, n_hidden, aggregator_type, feat_drop=dropout, activation=activation))
        # hidden layers
        for i in range(n_layers - 1):
            self.layers.append(SAGEConv(n_hidden, n_hidden, aggregator_type, feat_drop=dropout, activation=activation))
        # output layer
        self.layers.append(SAGEConv(n_hidden, n_classes, aggregator_type, feat_drop=dropout, activation=None)) # activation None

    def forward(self, features):
        h = features
        for layer in self.layers:
            h = layer(self.g, h)
        return h

# %%
def evaluate(model, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

def train(model, n_epochs):
    dur = []
    for epoch in range(n_epochs):
        model.train()
        if epoch >= 3:
            t0 = time.time()
        # forward
        logits = model(features)
        loss = loss_fcn(logits[train_mask], labels[train_mask])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if epoch >= 3:
            dur.append(time.time() - t0)

        acc = evaluate(model, features, labels, val_mask)
        print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | Accuracy {:.4f} | "
              "ETputs(KTEPS) {:.2f}".format(epoch, np.mean(dur), loss.item(),
                                            acc, n_edges / np.mean(dur) / 1000))

    print()
    acc = evaluate(model, features, labels, test_mask)
    print("Test Accuracy {:.4f}".format(acc))

# %%
parser = argparse.ArgumentParser(description='APPNP')
register_data_args(parser)
args = parser.parse_args(args=['--dataset', 'cora'])
#args = parser.parse_args(args=['--dataset', 'citeseer'])
#args = parser.parse_args(args=['--dataset', 'pubmed'])

data = load_data(args)
features = torch.FloatTensor(data.features)
labels = torch.LongTensor(data.labels)
if hasattr(torch, 'BoolTensor'):
    train_mask = torch.BoolTensor(data.train_mask)
    val_mask = torch.BoolTensor(data.val_mask)
    test_mask = torch.BoolTensor(data.test_mask)
else:
    train_mask = torch.ByteTensor(data.train_mask)
    val_mask = torch.ByteTensor(data.val_mask)
    test_mask = torch.ByteTensor(data.test_mask)
in_feats = features.shape[1]
n_classes = data.num_labels
n_edges = data.graph.number_of_edges()
print("""----Data statistics------'
  #Edges %d
  #Classes %d
  #Train samples %d
  #Val samples %d
  #Test samples %d""" %
      (n_edges, n_classes,
        train_mask.int().sum().item(),
        val_mask.int().sum().item(),
        test_mask.int().sum().item()))

if gpu < 0:
    cuda = False
else:
    cuda = True
    torch.cuda.set_device(gpu)
    features = features.cuda()
    labels = labels.cuda()
    train_mask = train_mask.cuda()
    val_mask = val_mask.cuda()
    test_mask = test_mask.cuda()
    print("use cuda:", gpu)
# Out:
# Downloading /root/.dgl/cora.zip from https://data.dgl.ai/dataset/cora_raw.zip...
# Extracting file to /root/.dgl/cora
# ----Data statistics------'
#   #Edges 10556
#   #Classes 7
#   #Train samples 140
#   #Val samples 300
#   #Test samples 1000
# use cuda: 0

# %%
g = data.graph
g.remove_edges_from(nx.selfloop_edges(g))
g = DGLGraph(g)
n_edges = g.number_of_edges()

# create GraphSAGE model
model = GraphSAGE(g,
                  in_feats,
                  n_hidden,
                  n_classes,
                  n_layers,
                  F.relu,
                  dropout,
                  aggregator_type
                  )

if cuda:
    model.cuda()
loss_fcn = torch.nn.CrossEntropyLoss()

# use optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# %%
train(model,200)
print("Train Accuracy",evaluate(model, features, labels, train_mask))
print("test Accuracy",evaluate(model, features, labels, test_mask))
# Out:
# Epoch 00000 | Time(s) nan | Loss 1.9610 | Accuracy 0.1267 | ETputs(KTEPS) nan
# Epoch 00001 | Time(s) nan | Loss 1.9342 | Accuracy 0.1267 | ETputs(KTEPS) nan
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00002 | Time(s) nan | Loss 1.9117 | Accuracy 0.2633 | ETputs(KTEPS) nan
# Epoch 00003 | Time(s) 0.0058 | Loss 1.8849 | Accuracy 0.4400 | ETputs(KTEPS) 1816.26
# Epoch 00004 | Time(s) 0.0055 | Loss 1.8609 | Accuracy 0.3600 | ETputs(KTEPS) 1916.50
# Epoch 00005 | Time(s) 0.0054 | Loss 1.8450 | Accuracy 0.3633 | ETputs(KTEPS) 1937.02
# Epoch 00006 | Time(s) 0.0054 | Loss 1.8252 | Accuracy 0.3867 | ETputs(KTEPS) 1972.91
# Epoch 00007 | Time(s) 0.0055 | Loss 1.7958 | Accuracy 0.4033 | ETputs(KTEPS) 1911.16
# Epoch 00008 | Time(s) 0.0055 | Loss 1.7729 | Accuracy 0.4100 | ETputs(KTEPS) 1926.16
# Epoch 00009 | Time(s) 0.0055 | Loss 1.7655 | Accuracy 0.4167 | ETputs(KTEPS) 1928.91
# Epoch 00010 | Time(s) 0.0054 | Loss 1.7277 | Accuracy 0.4167 | ETputs(KTEPS) 1942.54
# Epoch 00011 | Time(s) 0.0054 | Loss 1.7084 | Accuracy 0.4167 | ETputs(KTEPS) 1943.62
# Epoch 00012 | Time(s) 0.0055 | Loss 1.7029 | Accuracy 0.4167 | ETputs(KTEPS) 1932.84
# Epoch 00013 | Time(s) 0.0055 | Loss 1.6948 | Accuracy 0.4167 | ETputs(KTEPS) 1934.44
# Epoch 00014 | Time(s) 0.0054 | Loss 1.6604 | Accuracy 0.4167 | ETputs(KTEPS) 1937.82
# Epoch 00015 | Time(s) 0.0054 | Loss 1.6718 | Accuracy 0.4133 | ETputs(KTEPS) 1943.99
# Epoch 00016 | Time(s) 0.0054 | Loss 1.6354 | Accuracy 0.4100 | ETputs(KTEPS) 1944.41
# Epoch 00017 | Time(s) 0.0054 | Loss 1.6157 | Accuracy 0.4100 | ETputs(KTEPS) 1943.12
# Epoch 00018 | Time(s) 0.0054 | Loss 1.5725 | Accuracy 0.4100 | ETputs(KTEPS) 1945.42
# Epoch 00019 | Time(s) 0.0054 | Loss 1.6028 | Accuracy 0.4033 | ETputs(KTEPS) 1954.71
# Epoch 00020 | Time(s) 0.0054 | Loss 1.5750 | Accuracy 0.4033 | ETputs(KTEPS) 1947.22
# Epoch 00021 | Time(s) 0.0054 | Loss 1.5517 | Accuracy 0.4033 | ETputs(KTEPS) 1951.01
# Epoch 00022 | Time(s) 0.0054 | Loss 1.5451 | Accuracy 0.4033 | ETputs(KTEPS) 1959.79
# Epoch 00023 | Time(s) 0.0057 | Loss 1.5225 | Accuracy 0.4100 | ETputs(KTEPS) 1846.12
# Epoch 00024 | Time(s) 0.0057 | Loss 1.5035 | Accuracy 0.4100 | ETputs(KTEPS) 1844.78
# Epoch 00025 | Time(s) 0.0057 | Loss 1.4828 | Accuracy 0.4100 | ETputs(KTEPS) 1856.26
# Epoch 00026 | Time(s) 0.0057 | Loss 1.4521 | Accuracy 0.4100 | ETputs(KTEPS) 1865.22
# Epoch 00027 | Time(s) 0.0056 | Loss 1.4593 | Accuracy 0.4200 | ETputs(KTEPS) 1872.79
# Epoch 00028 | Time(s) 0.0056 | Loss 1.4330 | Accuracy 0.4467 | ETputs(KTEPS) 1883.29
# Epoch 00029 | Time(s) 0.0056 | Loss 1.4036 | Accuracy 0.4667 | ETputs(KTEPS) 1889.92
# Epoch 00030 | Time(s) 0.0056 | Loss 1.3920 | Accuracy 0.5067 | ETputs(KTEPS) 1897.01
# Epoch 00031 | Time(s) 0.0056 | Loss 1.3976 | Accuracy 0.5433 | ETputs(KTEPS) 1900.07
# Epoch 00032 | Time(s) 0.0056 | Loss 1.3604 | Accuracy 0.5733 | ETputs(KTEPS) 1900.90
# Epoch 00033 | Time(s) 0.0056 | Loss 1.3459 | Accuracy 0.5867 | ETputs(KTEPS) 1900.74
# Epoch 00034 | Time(s) 0.0055 | Loss 1.2908 | Accuracy 0.6033 | ETputs(KTEPS) 1907.68
# Epoch 00035 | Time(s) 0.0055 | Loss 1.3325 | Accuracy 0.6067 | ETputs(KTEPS) 1909.37
# Epoch 00036 | Time(s) 0.0055 | Loss 1.3122 | Accuracy 0.6133 | ETputs(KTEPS) 1911.45
# Epoch 00037 | Time(s) 0.0055 | Loss 1.2772 | Accuracy 0.6267 | ETputs(KTEPS) 1914.10
# Epoch 00038 | Time(s) 0.0055 | Loss 1.2500 | Accuracy 0.6300 | ETputs(KTEPS) 1918.27
# Epoch 00039 | Time(s) 0.0055 | Loss 1.2614 | Accuracy 0.6300 | ETputs(KTEPS) 1921.65
# Epoch 00040 | Time(s) 0.0055 | Loss 1.2029 | Accuracy 0.6367 | ETputs(KTEPS) 1920.27
# Epoch 00041 | Time(s) 0.0055 | Loss 1.2363 | Accuracy 0.6467 | ETputs(KTEPS) 1917.25
# Epoch 00066 | Time(s) 0.0055 | Loss 0.8715 | Accuracy 0.7633 | ETputs(KTEPS) 1921.60
# Epoch 00067 | Time(s) 0.0055 | Loss 0.8313 | Accuracy 0.7700 | ETputs(KTEPS) 1924.23
# Epoch 00068 | Time(s) 0.0055 | Loss 0.8111 | Accuracy 0.7733 | ETputs(KTEPS) 1927.31
# Epoch 00069 | Time(s) 0.0055 | Loss 0.8227 | Accuracy 0.7767 | ETputs(KTEPS) 1920.11
# Epoch 00070 | Time(s) 0.0055 | Loss 0.8330 | Accuracy 0.7800 | ETputs(KTEPS) 1923.10
# Epoch 00071 | Time(s) 0.0055 | Loss 0.8541 | Accuracy 0.7733 | ETputs(KTEPS) 1928.69
# Epoch 00072 | Time(s) 0.0055 | Loss 0.8304 | Accuracy 0.7700 | ETputs(KTEPS) 1934.53
# Epoch 00073 | Time(s) 0.0054 | Loss 0.8211 | Accuracy 0.7733 | ETputs(KTEPS) 1940.63
# Epoch 00074 | Time(s) 0.0054 | Loss 0.7551 | Accuracy 0.7800 | ETputs(KTEPS) 1948.34
# Epoch 00075 | Time(s) 0.0054 | Loss 0.8050 | Accuracy 0.7767 | ETputs(KTEPS) 1956.05
# Epoch 00076 | Time(s) 0.0054 | Loss 0.7667 | Accuracy 0.7767 | ETputs(KTEPS) 1963.38
# Epoch 00077 | Time(s) 0.0054 | Loss 0.7396 | Accuracy 0.7867 | ETputs(KTEPS) 1971.14
# Epoch 00078 | Time(s) 0.0053 | Loss 0.8077 | Accuracy 0.7967 | ETputs(KTEPS) 1978.55
# Epoch 00079 | Time(s) 0.0053 | Loss 0.7422 | Accuracy 0.8000 | ETputs(KTEPS) 1985.72
# Epoch 00080 | Time(s) 0.0053 | Loss 0.7383 | Accuracy 0.7967 | ETputs(KTEPS) 1992.86
# Epoch 00081 | Time(s) 0.0053 | Loss 0.7452 | Accuracy 0.8000 | ETputs(KTEPS) 1999.36
# Epoch 00082 | Time(s) 0.0053 | Loss 0.7721 | Accuracy 0.8000 | ETputs(KTEPS) 2006.19
# Epoch 00083 | Time(s) 0.0052 | Loss 0.6855 | Accuracy 0.8000 | ETputs(KTEPS) 2012.98
# Epoch 00084 | Time(s) 0.0052 | Loss 0.7645 | Accuracy 0.7967 | ETputs(KTEPS) 2019.66
# Epoch 00085 | Time(s) 0.0052 | Loss 0.7108 | Accuracy 0.7900 | ETputs(KTEPS) 2026.32
# Epoch 00086 | Time(s) 0.0052 | Loss 0.6796 | Accuracy 0.8000 | ETputs(KTEPS) 2032.73
# Epoch 00087 | Time(s) 0.0052 | Loss 0.6944 | Accuracy 0.8000 | ETputs(KTEPS) 2038.86
# Epoch 00088 | Time(s) 0.0052 | Loss 0.7139 | Accuracy 0.8000 | ETputs(KTEPS) 2044.89
# Epoch 00089 | Time(s) 0.0051 | Loss 0.6449 | Accuracy 0.8000 | ETputs(KTEPS) 2050.23
# Epoch 00090 | Time(s) 0.0051 | Loss 0.6337 | Accuracy 0.8000 | ETputs(KTEPS) 2056.29
# Epoch 00091 | Time(s) 0.0051 | Loss 0.6839 | Accuracy 0.8000 | ETputs(KTEPS) 2062.21
# Epoch 00092 | Time(s) 0.0051 | Loss 0.6759 | Accuracy 0.8000 | ETputs(KTEPS) 2061.35
# Epoch 00093 | Time(s) 0.0051 | Loss 0.6417 | Accuracy 0.8000 | ETputs(KTEPS) 2066.94
# Epoch 00094 | Time(s) 0.0051 | Loss 0.6633 | Accuracy 0.8000 | ETputs(KTEPS) 2072.64
# Epoch 00095 | Time(s) 0.0051 | Loss 0.6339 | Accuracy 0.7933 | ETputs(KTEPS) 2078.08
# Epoch 00096 | Time(s) 0.0051 | Loss 0.6308 | Accuracy 0.7933 | ETputs(KTEPS) 2083.24
# Epoch 00097 | Time(s) 0.0051 | Loss 0.6462 | Accuracy 0.7967 | ETputs(KTEPS) 2088.41
# Epoch 00098 | Time(s) 0.0050 | Loss 0.6535 | Accuracy 0.7933 | ETputs(KTEPS) 2093.77
# Epoch 00099 | Time(s) 0.0050 | Loss 0.5848 | Accuracy 0.7933 | ETputs(KTEPS) 2098.17
# Epoch 00100 | Time(s) 0.0050 | Loss 0.6535 | Accuracy 0.7967 | ETputs(KTEPS) 2090.55
# Epoch 00101 | Time(s) 0.0050 | Loss 0.5926 | Accuracy 0.7967 | ETputs(KTEPS) 2095.20
# Epoch 00102 | Time(s) 0.0050 | Loss 0.5916 | Accuracy 0.8100 | ETputs(KTEPS) 2100.12
# Epoch 00103 | Time(s) 0.0050 | Loss 0.5767 | Accuracy 0.8100 | ETputs(KTEPS) 2104.87
# Epoch 00104 | Time(s) 0.0050 | Loss 0.6130 | Accuracy 0.8100 | ETputs(KTEPS) 2107.59
# Epoch 00105 | Time(s) 0.0050 | Loss 0.5510 | Accuracy 0.8100 | ETputs(KTEPS) 2109.98
# Epoch 00106 | Time(s) 0.0050 | Loss 0.6331 | Accuracy 0.8133 | ETputs(KTEPS) 2111.59
# Epoch 00107 | Time(s) 0.0050 | Loss 0.5808 | Accuracy 0.8100 | ETputs(KTEPS) 2114.90
# Epoch 00108 | Time(s) 0.0050 | Loss 0.5100 | Accuracy 0.8067 | ETputs(KTEPS) 2119.26
# Epoch 00109 | Time(s) 0.0050 | Loss 0.5802 | Accuracy 0.8100 | ETputs(KTEPS) 2123.59
# Epoch 00110 | Time(s) 0.0050 | Loss 0.5710 | Accuracy 0.8000 | ETputs(KTEPS) 2128.15
# Epoch 00111 | Time(s) 0.0049 | Loss 0.5900 | Accuracy 0.8033 | ETputs(KTEPS) 2132.59
# Epoch 00112 | Time(s) 0.0049 | Loss 0.5519 | Accuracy 0.8033 | ETputs(KTEPS) 2137.08
# Epoch 00113 | Time(s) 0.0049 | Loss 0.6204 | Accuracy 0.8067 | ETputs(KTEPS) 2141.24
# Epoch 00114 | Time(s) 0.0049 | Loss 0.5752 | Accuracy 0.8033 | ETputs(KTEPS) 2145.42
# Epoch 00115 | Time(s) 0.0049 | Loss 0.5537 | Accuracy 0.8033 | ETputs(KTEPS) 2150.12
# Epoch 00116 | Time(s) 0.0049 | Loss 0.5616 | Accuracy 0.8033 | ETputs(KTEPS) 2154.08
# Epoch 00117 | Time(s) 0.0049 | Loss 0.5077 | Accuracy 0.8067 | ETputs(KTEPS) 2158.03
# Epoch 00118 | Time(s) 0.0049 | Loss 0.4854 | Accuracy 0.8100 | ETputs(KTEPS) 2162.04
# Epoch 00119 | Time(s) 0.0049 | Loss 0.5221 | Accuracy 0.8100 | ETputs(KTEPS) 2165.85
# Epoch 00120 | Time(s) 0.0049 | Loss 0.5152 | Accuracy 0.8133 | ETputs(KTEPS) 2169.76
# Epoch 00121 | Time(s) 0.0049 | Loss 0.5273 | Accuracy 0.8100 | ETputs(KTEPS) 2172.89
# Epoch 00122 | Time(s) 0.0048 | Loss 0.4854 | Accuracy 0.8100 | ETputs(KTEPS) 2176.82
# Epoch 00123 | Time(s) 0.0048 | Loss 0.5348 | Accuracy 0.8067 | ETputs(KTEPS) 2180.36
# Epoch 00124 | Time(s) 0.0048 | Loss 0.5505 | Accuracy 0.8067 | ETputs(KTEPS) 2184.16
# Epoch 00125 | Time(s) 0.0048 | Loss 0.5402 | Accuracy 0.8067 | ETputs(KTEPS) 2187.79
# Epoch 00126 | Time(s) 0.0048 | Loss 0.5560 | Accuracy 0.8067 | ETputs(KTEPS) 2191.44
# Epoch 00127 | Time(s) 0.0048 | Loss 0.5188 | Accuracy 0.8067 | ETputs(KTEPS) 2195.01
# Epoch 00128 | Time(s) 0.0048 | Loss 0.5316 | Accuracy 0.8100 | ETputs(KTEPS) 2198.38
# Epoch 00129 | Time(s) 0.0048 | Loss 0.5010 | Accuracy 0.8100 | ETputs(KTEPS) 2196.16
# Epoch 00130 | Time(s) 0.0048 | Loss 0.5142 | Accuracy 0.8167 | ETputs(KTEPS) 2195.75
# Epoch 00131 | Time(s) 0.0048 | Loss 0.5228 | Accuracy 0.8200 | ETputs(KTEPS) 2197.29
# Epoch 00132 | Time(s) 0.0048 | Loss 0.5177 | Accuracy 0.8233 | ETputs(KTEPS) 2199.01
# Epoch 00133 | Time(s) 0.0048 | Loss 0.5152 | Accuracy 0.8233 | ETputs(KTEPS) 2200.69
# Epoch 00134 | Time(s) 0.0048 | Loss 0.5076 | Accuracy 0.8233 | ETputs(KTEPS) 2199.98
# Epoch 00135 | Time(s) 0.0048 | Loss 0.4982 | Accuracy 0.8100 | ETputs(KTEPS) 2200.41
# Epoch 00136 | Time(s) 0.0048 | Loss 0.5123 | Accuracy 0.8033 | ETputs(KTEPS) 2201.81
# Epoch 00137 | Time(s) 0.0048 | Loss 0.5385 | Accuracy 0.7967 | ETputs(KTEPS) 2201.37
# Epoch 00138 | Time(s) 0.0048 | Loss 0.5261 | Accuracy 0.7933 | ETputs(KTEPS) 2203.10
# Epoch 00139 | Time(s) 0.0048 | Loss 0.5335 | Accuracy 0.7900 | ETputs(KTEPS) 2201.56
# Epoch 00140 | Time(s) 0.0048 | Loss 0.4907 | Accuracy 0.7933 | ETputs(KTEPS) 2201.65
# Epoch 00141 | Time(s) 0.0048 | Loss 0.4572 | Accuracy 0.8000 | ETputs(KTEPS) 2201.59
# Epoch 00142 | Time(s) 0.0048 | Loss 0.5074 | Accuracy 0.8233 | ETputs(KTEPS) 2198.71
# Epoch 00143 | Time(s) 0.0048 | Loss 0.4710 | Accuracy 0.8167 | ETputs(KTEPS) 2199.03
# Epoch 00144 | Time(s) 0.0048 | Loss 0.4643 | Accuracy 0.8167 | ETputs(KTEPS) 2199.67
# Epoch 00145 | Time(s) 0.0048 | Loss 0.4535 | Accuracy 0.8200 | ETputs(KTEPS) 2199.80
# Epoch 00146 | Time(s) 0.0048 | Loss 0.4705 | Accuracy 0.8200 | ETputs(KTEPS) 2198.71
# Epoch 00147 | Time(s) 0.0048 | Loss 0.5041 | Accuracy 0.8200 | ETputs(KTEPS) 2199.32
# Epoch 00148 | Time(s) 0.0048 | Loss 0.5411 | Accuracy 0.8200 | ETputs(KTEPS) 2200.58
# Epoch 00149 | Time(s) 0.0048 | Loss 0.4990 | Accuracy 0.8267 | ETputs(KTEPS) 2201.92
# Epoch 00150 | Time(s) 0.0048 | Loss 0.4450 | Accuracy 0.8167 | ETputs(KTEPS) 2203.45
# Epoch 00151 | Time(s) 0.0048 | Loss 0.4838 | Accuracy 0.8233 | ETputs(KTEPS) 2204.65
# Epoch 00152 | Time(s) 0.0048 | Loss 0.4636 | Accuracy 0.8167 | ETputs(KTEPS) 2206.02
# Epoch 00153 | Time(s) 0.0048 | Loss 0.4588 | Accuracy 0.8067 | ETputs(KTEPS) 2207.24
# Epoch 00154 | Time(s) 0.0048 | Loss 0.4426 | Accuracy 0.8100 | ETputs(KTEPS) 2208.76
# Epoch 00155 | Time(s) 0.0048 | Loss 0.4636 | Accuracy 0.8200 | ETputs(KTEPS) 2210.04
# Epoch 00156 | Time(s) 0.0048 | Loss 0.4531 | Accuracy 0.8167 | ETputs(KTEPS) 2211.26
# Epoch 00157 | Time(s) 0.0048 | Loss 0.4316 | Accuracy 0.8167 | ETputs(KTEPS) 2205.14
# Epoch 00158 | Time(s) 0.0048 | Loss 0.4220 | Accuracy 0.8167 | ETputs(KTEPS) 2206.07
# Epoch 00159 | Time(s) 0.0048 | Loss 0.4608 | Accuracy 0.8167 | ETputs(KTEPS) 2207.18
# Epoch 00160 | Time(s) 0.0048 | Loss 0.4621 | Accuracy 0.8200 | ETputs(KTEPS) 2208.20
# Epoch 00161 | Time(s) 0.0048 | Loss 0.4335 | Accuracy 0.8200 | ETputs(KTEPS) 2209.17
# Epoch 00162 | Time(s) 0.0048 | Loss 0.4382 | Accuracy 0.8200 | ETputs(KTEPS) 2210.16
# Epoch 00188 | Time(s) 0.0048 | Loss 0.3991 | Accuracy 0.8133 | ETputs(KTEPS) 2212.34
# Epoch 00189 | Time(s) 0.0048 | Loss 0.3792 | Accuracy 0.8100 | ETputs(KTEPS) 2211.58
# Epoch 00190 | Time(s) 0.0048 | Loss 0.4265 | Accuracy 0.8133 | ETputs(KTEPS) 2210.53
# Epoch 00191 | Time(s) 0.0048 | Loss 0.4140 | Accuracy 0.8133 | ETputs(KTEPS) 2208.83
# Epoch 00192 | Time(s) 0.0048 | Loss 0.4454 | Accuracy 0.8133 | ETputs(KTEPS) 2207.02
# Epoch 00193 | Time(s) 0.0048 | Loss 0.3982 | Accuracy 0.8100 | ETputs(KTEPS) 2204.95
# Epoch 00194 | Time(s) 0.0048 | Loss 0.4240 | Accuracy 0.8100 | ETputs(KTEPS) 2202.73
# Epoch 00195 | Time(s) 0.0048 | Loss 0.4054 | Accuracy 0.8167 | ETputs(KTEPS) 2201.11
# Epoch 00196 | Time(s) 0.0048 | Loss 0.4193 | Accuracy 0.8067 | ETputs(KTEPS) 2197.85
# Epoch 00197 | Time(s) 0.0048 | Loss 0.4052 | Accuracy 0.8033 | ETputs(KTEPS) 2196.04
# Epoch 00198 | Time(s) 0.0048 | Loss 0.4346 | Accuracy 0.8033 | ETputs(KTEPS) 2194.77
# Epoch 00199 | Time(s) 0.0048 | Loss 0.3810 | Accuracy 0.8067 | ETputs(KTEPS) 2193.08
#
# Test Accuracy 0.8240
# Train Accuracy 0.9785714285714285
# test Accuracy 0.824

# %%
def softmax_by_row(logits, T = 1.0):
    mx = np.max(logits, axis=-1, keepdims=True)
    exp = np.exp((logits - mx)/T)
    denominator = np.sum(exp, axis=-1, keepdims=True)
    return exp/denominator


def classifier_performance(model, features, labels, train_mask, test_mask):

    output_train = model(features)
    output_train = output_train[train_mask]
    output_train = output_train.cpu().detach().numpy()
    output_train = softmax_by_row(output_train,T = 1)
    train_labels = labels[train_mask].cpu().detach().numpy()


    output_test = model(features)
    output_test = output_test[test_mask]
    output_test=output_test.cpu().detach().numpy()
    output_test = softmax_by_row(output_test,T = 1)
    test_labels = labels[test_mask].cpu().detach().numpy()


    train_acc1 = np.sum(np.argmax(output_train,axis=1) == train_labels.flatten())/len(train_labels)
    test_acc1 = np.sum(np.argmax(output_test,axis=1) == test_labels.flatten())/len(test_labels)

    print('Accuracy: ', (train_acc1, test_acc1))

    return output_train, output_test, train_labels, test_labels




def inference_via_confidence(confidence_mtx1, confidence_mtx2, label_vec1, label_vec2):
    
    #----------------First step: obtain confidence lists for both training dataset and test dataset--------------
    confidence1 = []
    confidence2 = []
    acc1 = 0
    acc2 = 0
    for num in range(confidence_mtx1.shape[0]):
        confidence1.append(confidence_mtx1[num,label_vec1[num]])
        if np.argmax(confidence_mtx1[num,:]) == label_vec1[num]:
            acc1 += 1
            
    for num in range(confidence_mtx2.shape[0]):
        confidence2.append(confidence_mtx2[num,label_vec2[num]])
        if np.argmax(confidence_mtx2[num,:]) == label_vec2[num]:
            acc2 += 1
    confidence1 = np.array(confidence1)
    confidence2 = np.array(confidence2)
    
    print('model accuracy for training and test-', (acc1/confidence_mtx1.shape[0], acc2/confidence_mtx2.shape[0]) )
    
    
    #sort_confidence = np.sort(confidence1)
    sort_confidence = np.sort(np.concatenate((confidence1, confidence2)))
    max_accuracy = 0.5
    best_precision = 0.5
    best_recall = 0.5
    for num in range(len(sort_confidence)):
        delta = sort_confidence[num]
        ratio1 = np.sum(confidence1>=delta)/confidence_mtx1.shape[0]
        ratio2 = np.sum(confidence2>=delta)/confidence_mtx2.shape[0]
        accuracy_now = 0.5*(ratio1+1-ratio2)
        if accuracy_now > max_accuracy:
            max_accuracy = accuracy_now
            best_precision = ratio1/(ratio1+ratio2)
            best_recall = ratio1
    print('membership inference accuracy is:', max_accuracy)
    return max_accuracy

# %%
output_train, output_test, train_label, test_label = classifier_performance(model, features, labels, train_mask, test_mask)
inference_accuracy=inference_via_confidence(output_train, output_test, train_label, test_label)
print("Maximum Accuracy:",inference_accuracy)
# Out:
# Accuracy:  (0.9785714285714285, 0.824)
# model accuracy for training and test- (0.9785714285714285, 0.824)
# membership inference accuracy is: 0.6933571428571429
# Maximum Accuracy: 0.6933571428571429
